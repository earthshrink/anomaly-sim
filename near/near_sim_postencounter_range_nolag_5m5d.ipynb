# %% [markdown]
# # Test of post-encounter range data lag (unweighted)
#
# Light-time lags in simulated range data _should_ yield range-rate residuals identical to the Doppler residuals, with uniform oscillation extending indefinitely. Oscillation is seen but 3 orders too large and varying in amplitude.

# %%
from astropy import units as u
from astropy import constants as const
from astropy.time import Time

from poliastro.util import norm
from poliastro.frames import Planes
from poliastro.ephem import Ephem
from poliastro.bodies import Earth

from poliastro.twobody.orbit import Orbit
from poliastro.twobody.sampling import EpochsArray

from astropy.coordinates import solar_system_ephemeris

import numpy as np
import sys
sys.path.append('../')

from sim.stations import dss25, dss34
from sim.tracking import Tracking
from sim.util import describe_orbit, describe_state, describe_trajectory, find_swings

solar_system_ephemeris.set("de440")
goldstone_end = Tracking.NEAR_GOLDSTONE_END.value
canberra_start = Tracking.NEAR_CANBERRA_START.value
canberra_end = canberra_start + 5*u.day

# %%
sampling_interval = 600
sample_offsets = np.arange(0, (canberra_end-canberra_start)/(1*u.s), sampling_interval)
flyby_epochs = canberra_start + (sample_offsets << u.s)
print("Start and end epochs:", flyby_epochs[0], flyby_epochs[-1], "[", flyby_epochs.size, "]")
# Out:
# Start and end epochs: 1998-01-23 09:53:55.600 1998-01-28 09:43:55.600 [ 720 ]

# %%
near_goldstone_ephem = Ephem.from_horizons("NEAR", goldstone_end, attractor=Earth, plane=Planes.EARTH_EQUATOR)
near_goldstone_end_rv = near_goldstone_ephem.rv(goldstone_end)
describe_state(near_goldstone_end_rv, dss25, goldstone_end)

near_goldstone_orbit = Orbit.from_vectors(Earth, near_goldstone_end_rv[0], near_goldstone_end_rv[1], goldstone_end)
describe_orbit(near_goldstone_orbit)
# Out:
# :AT: 1998-01-23 06:14:55.600
# Geocentric distance: 37471.700215992445 km speed: 8.258344936971223 km / s
# From Goldstone-25 : range  31576.174442159892 km , range rate  -7.684513660227914 km / s
#
# ::ORBIT::
# Plane: Planes.EARTH_EQUATOR
# Inclination: 107.97266698121356 deg
# Eccentricity: 1.813357091534396
# Semilatus rectum: 19437.250829758486 km
# Semimajor axix: -8494.322039490264 km
# Periapse radius: 6908.917068596319 km , altitude: 530.7804685963192 km

# %%
near_extended_ephem = near_goldstone_orbit.to_ephem(EpochsArray(flyby_epochs))
describe_trajectory(near_extended_ephem, dss34)
# Out:
# ::TRAJECTORY::
# Start and end ranges: 77530.78379128852 km 3056567.1983871027 km
# Start and end radial speeds: 7.3216176182785535 km / s 6.7685218530996005 km / s
# Closest: 73145.82143191747 km speed 7.5891622264313146 km / s  at  1998-01-23 09:53:55.600
# Deflection: 0.45760516862302436 deg

# %%
sim_meas = []
for e in flyby_epochs:
    rv = near_extended_ephem.rv(e)
    ref_r, ref_rr, ref_ra = dss34.range_rate_accel(rv, e)
    #sim_meas.append([ref_r - ref_rr*ref_r/const.c])
    sim_meas.append([ref_r])

#print(sim_meas)

# %%
from sim.fitorbit import OrbitFitter
fitter = OrbitFitter(near_goldstone_orbit, [dss34], max_iter=25, var=0.001, debug=True, trace=True)
# Out:
# Range constraints:
# a: -8485827.717450773 -8502816.361529753
# ecc: 1.8115437344428615 1.8151704486259301
# inc: 1.8825940624405615 1.8863630195225243
# max iter: 25

# %%
from datetime import datetime 
start_time = datetime.now()
#print(start_time)

fitter.fit_range_data(flyby_epochs, sim_meas)
time_elapsed = datetime.now() - start_time
print(fitter.report())
print('Time elapsed (hh:mm:ss.ms) {}'.format(time_elapsed))

#print(fitter._resid)
#describe_orbit(fitter.orbit)
#describe_trajectory(fitter.ephem, dss34)
# Out:
# -1. 0.002172 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 0. 0.002172 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 1. 0.002172 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 2. 0.002172 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 3. 0.002172 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 4. 0.002172 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 5. 70.284885 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247364619576, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 6. 0.665369 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059276535786, 'argp': 2.533258385194789}
# 7. 0.892229 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.5332583941446405}
# 8. 0.001885 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247602001832, 'raan': 1.5400592550001355, 'argp': 2.5332583851970245}
# 8. 0.001885 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247602001832, 'raan': 1.5400592550001355, 'argp': 2.5332583851970245}
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 8
#     # data points      = 720
#     # variables        = 6
#     chi-square         = 3.5517e-06
#     reduced chi-square = 4.9744e-09
#     Akaike info crit   = -13759.6747
#     Bayesian info crit = -13732.1992
# ##  Warning: uncertainties could not be estimated:
#     a:     at initial value
#     ecc:   at initial value
#     inc:   at initial value
#     nu:    at initial value
#     raan:  at initial value
#     argp:  at initial value
# [[Variables]]
#     a:    -8494322.04 (init = -8494322)
#     ecc:   1.81335709 (init = 1.813357)
#     inc:   1.88447854 (init = 1.884479)
#     nu:   -1.83942476 (init = -1.839425)
#     raan:  1.54005926 (init = 1.540059)
#     argp:  2.53325839 (init = 2.533258)
# Time elapsed (hh:mm:ss.ms) 0:00:30.381881

# %%
import matplotlib.pylab as plt
import matplotlib.dates as mdates
from astropy import visualization
with visualization.time_support():
    fig, subf = plt.subplots(len(fitter._resid))
    fig.suptitle('Range residuals (m) over Canberra tracked time')
    for i, x in enumerate(fitter._resid):
        subf[i].plot(flyby_epochs[10:], x[10:], label='{:d}'.format(i))
        subf[i].legend(loc="best")
        if i < len(fitter._resid)-1:
            continue
        subf[i].xaxis.set_major_locator(mdates.DayLocator(interval=5))
    plt.gcf().autofmt_xdate()

# %%
range_rates = [v-fitter.result.residual[i-1] for i, v in enumerate(fitter.result.residual[1:])]

with visualization.time_support():
    fig, ax = plt.subplots()
    plt.xlabel('Canberra tracked time')
    plt.ylabel('Range rate residuals (m/s)')
    ax.plot(flyby_epochs[1:], range_rates, label='{:d}'.format(i))
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
    plt.gcf().autofmt_xdate()

# %%
peak_epochs, peak_swings = find_swings(flyby_epochs[1:], range_rates[1:])
with visualization.time_support():
    fig, ax = plt.subplots()
    plt.xlabel('NEAR 1998 flyby')
    plt.ylabel('Range rate swings (m/s)')
    plt.scatter(peak_epochs, peak_swings)
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
    plt.gcf().autofmt_xdate()

# %%
ratefitter = OrbitFitter(near_goldstone_orbit, [dss34], max_iter=50, var=0.001, debug=True, trace=True)
start_time = datetime.now()
#print(start_time)

ratefitter.fit_rangerates_to_range_data(flyby_epochs, sim_meas)
time_elapsed = datetime.now() - start_time
print(fitter.report())
print('Time elapsed (hh:mm:ss.ms) {}'.format(time_elapsed))

describe_orbit(fitter.orbit)
describe_trajectory(fitter.ephem, dss34)
# Out:
# Range constraints:
# a: -8485827.717450773 -8502816.361529753
# ecc: 1.8115437344428615 1.8151704486259301
# inc: 1.8825940624405615 1.8863630195225243
# max iter: 50
# -1. 92657.822388 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 0. 92657.822388 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 1. 92657.822388 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 2. 92657.822388 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 3. 92657.822388 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 4. 92657.822388 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 5. 92657.822376 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247364619576, 'raan': 1.540059254992049, 'argp': 2.533258385194789}
# 6. 92657.822389 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059276535786, 'argp': 2.533258385194789}
# 7. 92657.822389 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.8394247601999354, 'raan': 1.540059254992049, 'argp': 2.5332583941446405}
# 8. 101474.141801 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -3.0255840152462126, 'raan': 4.772008506618398, 'argp': 6.200958429928298}
# 9. 95516.535635 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 3.026604346649423, 'raan': 6.133308805971413, 'argp': 5.939508163664008}
# 10. 92949.337156 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': -1.3905869325336777, 'raan': 5.395650260033293, 'argp': 3.699251002272385}
# 11. 92533.733653 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068760584476593, 'raan': 1.650454442306533, 'argp': 2.5827337313782532}
# 12. 92533.733653 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068760584476593, 'raan': 1.650454442306533, 'argp': 2.5827337313782532}
# 13. 92533.733653 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068760584476593, 'raan': 1.650454442306533, 'argp': 2.5827337313782532}
# 14. 92533.733653 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068760584476593, 'raan': 1.650454442306533, 'argp': 2.5827337313782532}
# 15. 92533.733656 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068759207927531, 'raan': 1.650454442306533, 'argp': 2.5827337313782532}
# 16. 92533.733654 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068760584476593, 'raan': 1.650454462684414, 'argp': 2.5827337313782532}
# 17. 92533.733654 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.5068760584476593, 'raan': 1.650454442306533, 'argp': 2.5827337396169248}
# 18. 99291.307735 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 3.133911840556455, 'raan': 0.5996445908207174, 'argp': 2.209806732748927}
# 19. 92522.704321 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204303817497559, 'raan': 1.5194572783885185, 'argp': 2.545818216200292}
# 20. 92522.704321 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204303817497559, 'raan': 1.5194572783885185, 'argp': 2.545818216200292}
# 21. 92522.704321 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204303817497559, 'raan': 1.5194572783885185, 'argp': 2.545818216200292}
# 22. 92522.704321 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204303817497559, 'raan': 1.5194572783885185, 'argp': 2.545818216200292}
# 23. 92522.704324 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204302544437288, 'raan': 1.5194572783885185, 'argp': 2.545818216200292}
# 24. 92522.704321 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204303817497559, 'raan': 1.5194573001403855, 'argp': 2.545818216200292}
# 25. 92522.704321 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 0.9204303817497559, 'raan': 1.5194572783885185, 'argp': 2.5458182249700347}
# 26. 92453.309122 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.7965242909451238, 'raan': 1.3755284324487977, 'argp': 2.5009453055964395}
# 27. 92453.309122 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.7965242909451238, 'raan': 1.3755284324487977, 'argp': 2.5009453055964395}
# 28. 92453.309122 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.7965242909451238, 'raan': 1.3755284324487977, 'argp': 2.5009453055964395}
# 29. 92453.309122 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.7965242909451238, 'raan': 1.3755284324487977, 'argp': 2.5009453055964395}
# 30. 92453.309147 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.796524193675034, 'raan': 1.3755284324487977, 'argp': 2.5009453055964395}
# 31. 92453.309122 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.7965242909451238, 'raan': 1.3755284555619451, 'argp': 2.5009453055964395}
# 32. 92453.309122 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.7965242909451238, 'raan': 1.3755284324487977, 'argp': 2.5009453150082446}
# 33. 101656.422151 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 3.0017294130511587, 'raan': 1.3614022759773001, 'argp': 2.4983868834494536}
# 34. 92371.698556 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.9684229502169934, 'raan': 1.3741634595516274, 'argp': 2.5004355542395644}
# 35. 92371.698556 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.9684229502169934, 'raan': 1.3741634595516274, 'argp': 2.5004355542395644}
# 36. 92371.698556 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.9684229502169934, 'raan': 1.3741634595516274, 'argp': 2.5004355542395644}
# 37. 92371.698556 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.9684229502169934, 'raan': 1.3741634595516274, 'argp': 2.5004355542395644}
# 38. 92371.698633 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.968422860302085, 'raan': 1.3741634595516274, 'argp': 2.5004355542395644}
# 39. 92371.698556 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.9684229502169934, 'raan': 1.3741634826768527, 'argp': 2.5004355542395644}
# 40. 92371.698556 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 1.9684229502169934, 'raan': 1.3741634595516274, 'argp': 2.50043556365864}
# 41. 91963.540800 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224566284016915, 'raan': 1.3733567493673746, 'argp': 2.5002707869262797}
# 42. 91963.540800 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224566284016915, 'raan': 1.3733567493673746, 'argp': 2.5002707869262797}
# 43. 91963.540800 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224566284016915, 'raan': 1.3733567493673746, 'argp': 2.5002707869262797}
# 44. 91963.540800 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224566284016915, 'raan': 1.3733567493673746, 'argp': 2.5002707869262797}
# 45. 91963.584088 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.2245662061784257, 'raan': 1.3733567493673746, 'argp': 2.5002707869262797}
# 46. 91963.540783 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224566284016915, 'raan': 1.3733567724997298, 'argp': 2.5002707869262797}
# 47. 91963.540824 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224566284016915, 'raan': 1.3733567493673746, 'argp': 2.5002707963477055}
# 48. 91634.990454 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224630041722289, 'raan': 1.4104087134636025, 'argp': 2.395472968921377}
# 49. 91634.990454 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224630041722289, 'raan': 1.4104087134636025, 'argp': 2.395472968921377}
# 50. 91634.990454 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224630041722289, 'raan': 1.4104087134636025, 'argp': 2.395472968921377}
# 50. 91634.990454 {'a': -8494322.039490264, 'ecc': 1.813357091534396, 'inc': 1.884478540981543, 'nu': 2.224630041722289, 'raan': 1.4104087134636025, 'argp': 2.395472968921377}
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 8
#     # data points      = 720
#     # variables        = 6
#     chi-square         = 3.5517e-06
#     reduced chi-square = 4.9744e-09
#     Akaike info crit   = -13759.6747
#     Bayesian info crit = -13732.1992
# ##  Warning: uncertainties could not be estimated:
#     a:     at initial value
#     ecc:   at initial value
#     inc:   at initial value
#     nu:    at initial value
#     raan:  at initial value
#     argp:  at initial value
# [[Variables]]
#     a:    -8494322.04 (init = -8494322)
#     ecc:   1.81335709 (init = 1.813357)
#     inc:   1.88447854 (init = 1.884479)
#     nu:   -1.83942476 (init = -1.839425)
#     raan:  1.54005926 (init = 1.540059)
#     argp:  2.53325839 (init = 2.533258)
# Time elapsed (hh:mm:ss.ms) 0:02:27.237021
#
# ::ORBIT::
# Plane: Planes.EARTH_EQUATOR
# Inclination: 107.97266698121356 deg
# Eccentricity: 1.813357091534396
# Semilatus rectum: 19437250.829758488 m
# Semimajor axix: -8494322.039490264 m
# Periapse radius: 6908917.068596319 m , altitude: 530780.4685963197 m
#
# ::TRAJECTORY::
# Start and end ranges: 77530.783791256 km 3056567.198387263 km
# Start and end radial speeds: 7.321617618279619 km / s 6.768521853099712 km / s
# Closest: 73145.82143188447 km speed 7.589162226431592 km / s  at  1998-01-23 09:53:55.600
# Deflection: 0.4576051686238209 deg

# %%
with visualization.time_support():
    fig, ax = plt.subplots()
    plt.xlabel('Canberra tracked time')
    plt.ylabel('Range rate residuals (m/s)')
    ax.plot(flyby_epochs[1:], ratefitter.result.residual, label='{:d}'.format(i))
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
    plt.gcf().autofmt_xdate()

# %%
peak_epochs, peak_swings = find_swings(flyby_epochs[1:], ratefitter.result.residual)
with visualization.time_support():
    fig, ax = plt.subplots()
    plt.xlabel('NEAR 1998 flyby')
    plt.ylabel('Range rate swings (m/s)')
    plt.scatter(peak_epochs, peak_swings)
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
    plt.gcf().autofmt_xdate()

# %%
print(peak_swings[0], peak_swings[-1])
# Out:
# 537.3912178298524 703.7544406098732
